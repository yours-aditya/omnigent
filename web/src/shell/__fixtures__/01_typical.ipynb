# %% [markdown]
# # Sales Analysis
#
# Exploring **Q3 data** with a quick plot.
#
# - load
# - clean
# - plot

# %%
import pandas as pd
df = pd.read_csv('sales.csv')
print(f'rows: {len(df)}')
# Out:
# rows: 1523

# %%
df.describe()
# Out:
#        amount
# count  1523.0
# mean    47.3
# std   12.1

# %%
df.plot()
